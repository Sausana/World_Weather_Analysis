# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
from config import weather_api_key

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-200,high=200,size=2000)
lngs = np.random.uniform(low=-100,high=100,size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
coordinates = zip(lats,lngs)
coordinates

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
# YOUR CODE HERE
cities=[]
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 420

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_url = url + "&q=" + city[1].replace(" ","+")
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d3d81e2ad214e746479d6b155a418fd&q=n

# %%
 city_weather = requests.get(city_url).json()
 print(city_weather)
# Out:
# {'cod': '404', 'message': 'city not found'}

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
city_weather = requests.get(city_url).json()

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE  
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        
   
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": weather_description})


    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | abnub
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | krutinka
# Processing Record 4 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 1 | qaanaaq
# Processing Record 6 of Set 1 | barbosa ferraz
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | tasiilaq
# Processing Record 9 of Set 1 | berlevag
# Processing Record 10 of Set 1 | dikson
# Processing Record 11 of Set 1 | fort frances
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | robertson
# Processing Record 15 of Set 1 | longyearbyen
# Processing Record 16 of Set 1 | tazovskiy
# Processing Record 17 of Set 1 | upernavik
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | vilhena
# Processing Record 20 of Set 1 | jamestown
# Processing Record 21 of Set 1 | laguna
# Processing Record 22 of Set 1 | bredasdorp
# Processing Record 23 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 1 | petrila
# Processing Record 25 of Set 1 | san cristobal
# Processing Record 26 of Set 1 | victoria
# Processing Record 27 of Set 1 | castro
# Processing Record 28 of Set 1 | copiapo
# Processing Record 29 of Set 1 | sambava
# Processing Record 30 of Set 1 | khatanga
# Processing Record 31 of Set 1 | buguruslan
# Processing Record 32 of Set 1 | loukhi
# Processing Record 33 of Set 1 | port elizabeth
# Processing Record 34 of Set 1 | labuhan
# Processing Record 35 of Set 1 | narsaq
# Processing Record 36 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 1 | arraial do cabo
# Processing Record 38 of Set 1 | wilmington
# Processing Record 39 of Set 1 | parakou
# Processing Record 40 of Set 1 | kruisfontein
# Processing Record 41 of Set 1 | kjollefjord
# Processing Record 42 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 1 | talnakh
# Processing Record 46 of Set 1 | nizhniy baskunchak
# Processing Record 47 of Set 1 | hobart
# Processing Record 48 of Set 1 | ilulissat
# Processing Record 49 of Set 1 | dogondoutchi
# Processing Record 50 of Set 1 | bereda
# Processing Record 1 of Set 2 | la romana
# Processing Record 2 of Set 2 | busselton
# Processing Record 3 of Set 2 | freeport
# Processing Record 4 of Set 2 | pagman
# City not found. Skipping...
# Processing Record 5 of Set 2 | mbini
# Processing Record 6 of Set 2 | sebinkarahisar
# Processing Record 7 of Set 2 | bodmin
# Processing Record 8 of Set 2 | cotonou
# Processing Record 9 of Set 2 | gornyy
# Processing Record 10 of Set 2 | soyo
# Processing Record 11 of Set 2 | westerly
# Processing Record 12 of Set 2 | tromso
# Processing Record 13 of Set 2 | concepcion del uruguay
# Processing Record 14 of Set 2 | sadon
# Processing Record 15 of Set 2 | tarasovskiy
# Processing Record 16 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 2 | georgetown
# Processing Record 18 of Set 2 | salalah
# Processing Record 19 of Set 2 | itaituba
# Processing Record 20 of Set 2 | jalu
# Processing Record 21 of Set 2 | cape town
# Processing Record 22 of Set 2 | codrington
# Processing Record 23 of Set 2 | aksarka
# Processing Record 24 of Set 2 | guarapari
# Processing Record 25 of Set 2 | atar
# Processing Record 26 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 2 | kavaratti
# Processing Record 28 of Set 2 | nanortalik
# Processing Record 29 of Set 2 | bafoulabe
# Processing Record 30 of Set 2 | bamboo
# Processing Record 31 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 2 | rawson
# Processing Record 33 of Set 2 | umm lajj
# Processing Record 34 of Set 2 | kharp
# Processing Record 35 of Set 2 | luderitz
# Processing Record 36 of Set 2 | inhambane
# Processing Record 37 of Set 2 | hithadhoo
# Processing Record 38 of Set 2 | mahebourg
# Processing Record 39 of Set 2 | tirthahalli
# Processing Record 40 of Set 2 | maniitsoq
# Processing Record 41 of Set 2 | lagoa
# Processing Record 42 of Set 2 | iskateley
# Processing Record 43 of Set 2 | tawkar
# City not found. Skipping...
# Processing Record 44 of Set 2 | diffa
# Processing Record 45 of Set 2 | klaksvik
# Processing Record 46 of Set 2 | yar-sale
# Processing Record 47 of Set 2 | constitucion
# Processing Record 48 of Set 2 | manicore
# Processing Record 49 of Set 2 | meulaboh
# Processing Record 50 of Set 2 | uaua
# Processing Record 1 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 2 of Set 3 | buraydah
# Processing Record 3 of Set 3 | chapais
# Processing Record 4 of Set 3 | kayes
# Processing Record 5 of Set 3 | taltal
# Processing Record 6 of Set 3 | sao filipe
# Processing Record 7 of Set 3 | verkh-suetka
# Processing Record 8 of Set 3 | samana
# Processing Record 9 of Set 3 | aquiraz
# Processing Record 10 of Set 3 | fecamp
# Processing Record 11 of Set 3 | maldonado
# Processing Record 12 of Set 3 | monrovia
# Processing Record 13 of Set 3 | norvenich
# Processing Record 14 of Set 3 | puerto ayora
# Processing Record 15 of Set 3 | sumter
# Processing Record 16 of Set 3 | oxford
# Processing Record 17 of Set 3 | thompson
# Processing Record 18 of Set 3 | ouesso
# Processing Record 19 of Set 3 | paamiut
# Processing Record 20 of Set 3 | lewisporte
# Processing Record 21 of Set 3 | port-cartier
# Processing Record 22 of Set 3 | tarata
# Processing Record 23 of Set 3 | bubaque
# Processing Record 24 of Set 3 | east london
# Processing Record 25 of Set 3 | kalmunai
# Processing Record 26 of Set 3 | turukhansk
# Processing Record 27 of Set 3 | iqaluit
# Processing Record 28 of Set 3 | kantang
# Processing Record 29 of Set 3 | coquimbo
# Processing Record 30 of Set 3 | saldanha
# Processing Record 31 of Set 3 | saint-pierre
# Processing Record 32 of Set 3 | oriximina
# Processing Record 33 of Set 3 | kozhva
# Processing Record 34 of Set 3 | puerto lempira
# Processing Record 35 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 3 | pisco
# Processing Record 37 of Set 3 | altamira
# Processing Record 38 of Set 3 | bykovo
# Processing Record 39 of Set 3 | ponta delgada
# Processing Record 40 of Set 3 | henties bay
# Processing Record 41 of Set 3 | mogadishu
# Processing Record 42 of Set 3 | reconquista
# Processing Record 43 of Set 3 | harper
# Processing Record 44 of Set 3 | lebu
# Processing Record 45 of Set 3 | blagoyevo
# Processing Record 46 of Set 3 | qaqortoq
# Processing Record 47 of Set 3 | vestmannaeyjar
# Processing Record 48 of Set 3 | assai
# Processing Record 49 of Set 3 | hofn
# Processing Record 50 of Set 3 | nalut
# Processing Record 1 of Set 4 | souillac
# Processing Record 2 of Set 4 | cabedelo
# Processing Record 3 of Set 4 | stamsund
# City not found. Skipping...
# Processing Record 4 of Set 4 | placido de castro
# Processing Record 5 of Set 4 | nacogdoches
# Processing Record 6 of Set 4 | neuquen
# Processing Record 7 of Set 4 | rio gallegos
# Processing Record 8 of Set 4 | san-pedro
# Processing Record 9 of Set 4 | benjamin constant
# Processing Record 10 of Set 4 | saint-philippe
# Processing Record 11 of Set 4 | goderich
# Processing Record 12 of Set 4 | bikramganj
# Processing Record 13 of Set 4 | comodoro rivadavia
# Processing Record 14 of Set 4 | plouzane
# Processing Record 15 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 4 | djambala
# Processing Record 17 of Set 4 | eskasem
# City not found. Skipping...
# Processing Record 18 of Set 4 | gurlan
# Processing Record 19 of Set 4 | vytegra
# Processing Record 20 of Set 4 | san carlos de bariloche
# Processing Record 21 of Set 4 | namibe
# Processing Record 22 of Set 4 | bambous virieux
# Processing Record 23 of Set 4 | tabou
# Processing Record 24 of Set 4 | diego de almagro
# Processing Record 25 of Set 4 | sovetskiy
# Processing Record 26 of Set 4 | new norfolk
# Processing Record 27 of Set 4 | saint george
# Processing Record 28 of Set 4 | cururupu
# Processing Record 29 of Set 4 | amapa
# Processing Record 30 of Set 4 | moose factory
# Processing Record 31 of Set 4 | matamoros
# Processing Record 32 of Set 4 | nizwa
# Processing Record 33 of Set 4 | salekhard
# Processing Record 34 of Set 4 | vardo
# Processing Record 35 of Set 4 | irbit
# Processing Record 36 of Set 4 | sinkat
# City not found. Skipping...
# Processing Record 37 of Set 4 | cockburn town
# Processing Record 38 of Set 4 | edwardsville
# Processing Record 39 of Set 4 | qandala
# Processing Record 40 of Set 4 | kommunisticheskiy
# Processing Record 41 of Set 4 | litokhoron
# City not found. Skipping...
# Processing Record 42 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 4 | clyde river
# Processing Record 44 of Set 4 | ribeira grande
# Processing Record 45 of Set 4 | hobe sound
# Processing Record 46 of Set 4 | ilmenau
# Processing Record 47 of Set 4 | andenes
# Processing Record 48 of Set 4 | hobyo
# Processing Record 49 of Set 4 | porosozero
# Processing Record 50 of Set 4 | visnes
# Processing Record 1 of Set 5 | tambul
# City not found. Skipping...
# Processing Record 2 of Set 5 | ostrovnoy
# Processing Record 3 of Set 5 | sao jose da coroa grande
# Processing Record 4 of Set 5 | zwedru
# Processing Record 5 of Set 5 | walvis bay
# Processing Record 6 of Set 5 | carnarvon
# Processing Record 7 of Set 5 | iquitos
# Processing Record 8 of Set 5 | santa cruz
# Processing Record 9 of Set 5 | kutum
# Processing Record 10 of Set 5 | tiznit
# Processing Record 11 of Set 5 | garoua
# Processing Record 12 of Set 5 | port-gentil
# Processing Record 13 of Set 5 | trofors
# Processing Record 14 of Set 5 | galle
# Processing Record 15 of Set 5 | sao joao da barra
# Processing Record 16 of Set 5 | ottappalam
# Processing Record 17 of Set 5 | oltu
# Processing Record 18 of Set 5 | thinadhoo
# Processing Record 19 of Set 5 | margate
# Processing Record 20 of Set 5 | bayana
# Processing Record 21 of Set 5 | skagastrond
# City not found. Skipping...
# Processing Record 22 of Set 5 | mar del plata
# Processing Record 23 of Set 5 | vila franca do campo
# Processing Record 24 of Set 5 | sioux lookout
# Processing Record 25 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 26 of Set 5 | hualmay
# Processing Record 27 of Set 5 | prado
# Processing Record 28 of Set 5 | khowst
# Processing Record 29 of Set 5 | upata
# Processing Record 30 of Set 5 | san jeronimo de tunan
# City not found. Skipping...
# Processing Record 31 of Set 5 | serrinha
# Processing Record 32 of Set 5 | bonfim
# Processing Record 33 of Set 5 | acajutla
# Processing Record 34 of Set 5 | arenys de mar
# Processing Record 35 of Set 5 | itainopolis
# Processing Record 36 of Set 5 | itarema
# Processing Record 37 of Set 5 | robertsport
# Processing Record 38 of Set 5 | maraba
# Processing Record 39 of Set 5 | cidreira
# Processing Record 40 of Set 5 | marsh harbour
# Processing Record 41 of Set 5 | grand gaube
# Processing Record 42 of Set 5 | dibaya
# City not found. Skipping...
# Processing Record 43 of Set 5 | lieksa
# Processing Record 44 of Set 5 | marquette
# Processing Record 45 of Set 5 | camana
# Processing Record 46 of Set 5 | kerki
# City not found. Skipping...
# Processing Record 47 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 48 of Set 5 | krasnoselkup
# Processing Record 49 of Set 5 | laela
# Processing Record 50 of Set 5 | sandhaven
# City not found. Skipping...
# Processing Record 1 of Set 6 | albina
# Processing Record 2 of Set 6 | yellowknife
# Processing Record 3 of Set 6 | mezen
# Processing Record 4 of Set 6 | povenets
# Processing Record 5 of Set 6 | parauna
# Processing Record 6 of Set 6 | bengkulu
# Processing Record 7 of Set 6 | capitao poco
# Processing Record 8 of Set 6 | nara
# Processing Record 9 of Set 6 | husavik
# Processing Record 10 of Set 6 | alberton
# Processing Record 11 of Set 6 | mayor pablo lagerenza
# Processing Record 12 of Set 6 | kouango
# Processing Record 13 of Set 6 | madhogarh
# Processing Record 14 of Set 6 | trifesti
# Processing Record 15 of Set 6 | kuytun
# Processing Record 16 of Set 6 | itupeva
# Processing Record 17 of Set 6 | nuuk
# Processing Record 18 of Set 6 | coari
# Processing Record 19 of Set 6 | zaria
# Processing Record 20 of Set 6 | mehamn
# Processing Record 21 of Set 6 | saurimo
# Processing Record 22 of Set 6 | havre-saint-pierre
# Processing Record 23 of Set 6 | bathsheba
# Processing Record 24 of Set 6 | tura
# Processing Record 25 of Set 6 | corinto
# Processing Record 26 of Set 6 | edd
# Processing Record 27 of Set 6 | prieska
# Processing Record 28 of Set 6 | moron
# Processing Record 29 of Set 6 | itigi
# Processing Record 30 of Set 6 | koungheul
# Processing Record 31 of Set 6 | dingle
# Processing Record 32 of Set 6 | tahoua
# Processing Record 33 of Set 6 | nokaneng
# Processing Record 34 of Set 6 | matara
# Processing Record 35 of Set 6 | chuy
# Processing Record 36 of Set 6 | cilaos
# Processing Record 37 of Set 6 | eten
# Processing Record 38 of Set 6 | madingou
# Processing Record 39 of Set 6 | la palma
# Processing Record 40 of Set 6 | hamilton
# Processing Record 41 of Set 6 | gualeguay
# Processing Record 42 of Set 6 | gat
# Processing Record 43 of Set 6 | barentu
# Processing Record 44 of Set 6 | prestea
# Processing Record 45 of Set 6 | touros
# Processing Record 46 of Set 6 | humaita
# Processing Record 47 of Set 6 | geraldton
# Processing Record 48 of Set 6 | prijepolje
# Processing Record 49 of Set 6 | oyem
# Processing Record 50 of Set 6 | normal
# Processing Record 1 of Set 7 | alta floresta
# Processing Record 2 of Set 7 | yenagoa
# Processing Record 3 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 4 of Set 7 | zelenets
# Processing Record 5 of Set 7 | asyut
# Processing Record 6 of Set 7 | west bay
# Processing Record 7 of Set 7 | ulvila
# Processing Record 8 of Set 7 | jhikargachha
# City not found. Skipping...
# Processing Record 9 of Set 7 | abalak
# Processing Record 10 of Set 7 | darab
# Processing Record 11 of Set 7 | torbay
# Processing Record 12 of Set 7 | werda
# Processing Record 13 of Set 7 | nuzvid
# Processing Record 14 of Set 7 | ambilobe
# Processing Record 15 of Set 7 | turayf
# Processing Record 16 of Set 7 | saint-francois
# Processing Record 17 of Set 7 | elat
# Processing Record 18 of Set 7 | chicama
# Processing Record 19 of Set 7 | bentiu
# Processing Record 20 of Set 7 | jijiga
# Processing Record 21 of Set 7 | ponta do sol
# Processing Record 22 of Set 7 | jolalpan
# Processing Record 23 of Set 7 | rengali
# Processing Record 24 of Set 7 | necochea
# Processing Record 25 of Set 7 | kasese
# Processing Record 26 of Set 7 | awbari
# Processing Record 27 of Set 7 | jvari
# Processing Record 28 of Set 7 | porangatu
# Processing Record 29 of Set 7 | shelburne
# Processing Record 30 of Set 7 | saint-augustin
# Processing Record 31 of Set 7 | vallenar
# Processing Record 32 of Set 7 | hami
# Processing Record 33 of Set 7 | fougamou
# Processing Record 34 of Set 7 | saint-leu
# Processing Record 35 of Set 7 | axim
# Processing Record 36 of Set 7 | puerto rondon
# Processing Record 37 of Set 7 | ancud
# Processing Record 38 of Set 7 | mumbwa
# Processing Record 39 of Set 7 | viedma
# Processing Record 40 of Set 7 | uch
# Processing Record 41 of Set 7 | riyadh
# Processing Record 42 of Set 7 | vicksburg
# Processing Record 43 of Set 7 | taseyevo
# Processing Record 44 of Set 7 | inta
# Processing Record 45 of Set 7 | salumbar
# Processing Record 46 of Set 7 | andevoranto
# City not found. Skipping...
# Processing Record 47 of Set 7 | kismayo
# Processing Record 48 of Set 7 | ambovombe
# Processing Record 49 of Set 7 | lubango
# Processing Record 50 of Set 7 | havelock
# Processing Record 1 of Set 8 | naron
# Processing Record 2 of Set 8 | erzin
# Processing Record 3 of Set 8 | strezhevoy
# Processing Record 4 of Set 8 | alakurtti
# Processing Record 5 of Set 8 | cuamba
# Processing Record 6 of Set 8 | hendijan
# City not found. Skipping...
# Processing Record 7 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 8 of Set 8 | port blair
# Processing Record 9 of Set 8 | birsk
# Processing Record 10 of Set 8 | calama
# Processing Record 11 of Set 8 | weligama
# Processing Record 12 of Set 8 | lisakovsk
# Processing Record 13 of Set 8 | lakhimpur
# Processing Record 14 of Set 8 | frontera
# Processing Record 15 of Set 8 | nowy tomysl
# Processing Record 16 of Set 8 | ler
# Processing Record 17 of Set 8 | virbhadra
# Processing Record 18 of Set 8 | cambrils
# Processing Record 19 of Set 8 | ponnani
# Processing Record 20 of Set 8 | grand-santi
# Processing Record 21 of Set 8 | baykit
# Processing Record 22 of Set 8 | acarau
# Processing Record 23 of Set 8 | mana
# Processing Record 24 of Set 8 | galgani
# City not found. Skipping...
# Processing Record 25 of Set 8 | bristol
# Processing Record 26 of Set 8 | beloha
# Processing Record 27 of Set 8 | sioux falls
# Processing Record 28 of Set 8 | la libertad
# Processing Record 29 of Set 8 | barhi
# Processing Record 30 of Set 8 | isoka
# Processing Record 31 of Set 8 | karlstad
# Processing Record 32 of Set 8 | kamenka
# Processing Record 33 of Set 8 | adrar
# Processing Record 34 of Set 8 | uusikaupunki
# Processing Record 35 of Set 8 | puerto madryn
# Processing Record 36 of Set 8 | pirgos
# Processing Record 37 of Set 8 | maradi
# Processing Record 38 of Set 8 | cap malheureux
# Processing Record 39 of Set 8 | shetpe
# Processing Record 40 of Set 8 | gurgan
# City not found. Skipping...
# Processing Record 41 of Set 8 | pochutla
# Processing Record 42 of Set 8 | tonantins
# Processing Record 43 of Set 8 | manta
# Processing Record 44 of Set 8 | teya
# Processing Record 45 of Set 8 | lourdes
# Processing Record 46 of Set 8 | roatan
# Processing Record 47 of Set 8 | kodumudi
# Processing Record 48 of Set 8 | gazojak
# Processing Record 49 of Set 8 | santiago de cuba
# Processing Record 50 of Set 8 | sakakah
# Processing Record 1 of Set 9 | zahir pir
# Processing Record 2 of Set 9 | saint anthony
# Processing Record 3 of Set 9 | tambopata
# Processing Record 4 of Set 9 | tarauaca
# Processing Record 5 of Set 9 | lethem
# Processing Record 6 of Set 9 | rudsar
# Processing Record 7 of Set 9 | jiuquan
# Processing Record 8 of Set 9 | guiratinga
# Processing Record 9 of Set 9 | attert
# Processing Record 10 of Set 9 | xuddur
# Processing Record 11 of Set 9 | ust-tsilma
# Processing Record 12 of Set 9 | mahibadhoo
# Processing Record 13 of Set 9 | samoded
# Processing Record 14 of Set 9 | presidencia roque saenz pena
# Processing Record 15 of Set 9 | nizhnyaya poyma
# Processing Record 16 of Set 9 | mahenge
# Processing Record 17 of Set 9 | dodoma
# Processing Record 18 of Set 9 | hammerfest
# Processing Record 19 of Set 9 | agarak
# Processing Record 20 of Set 9 | enid
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 386

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df =pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0           Abnub  27.2696  31.1511     73.62        36           0
# 1          Albany  42.6001 -73.9662     69.26        55          29
# 2        Krutinka  56.0055  71.5113     34.36        95         100
# 3         Qaanaaq  77.4840 -69.3632     18.93        66         100
# 4  Barbosa Ferraz -24.0300 -52.0117     74.43        45           0
# 5     Port Alfred -33.5906  26.8910     69.19        89          82
# 6        Tasiilaq  65.6145 -37.6368     30.36        83         100
# 7        Berlevag  70.8578  29.0864     41.00        81          75
# 8          Dikson  73.5069  80.5464     20.57        96          98
# 9    Fort Frances  48.5999 -93.4003     33.17        75          40
#
#    Wind Speed Country                 Date Current Description
# 0       10.25      EG  2022-11-04 17:31:21           clear sky
# 1        3.00      US  2022-11-04 17:31:21    scattered clouds
# 2       17.85      RU  2022-11-04 17:31:21                snow
# 3        7.63      GL  2022-11-04 17:31:21     overcast clouds
# 4        2.73      BR  2022-11-04 17:31:21           clear sky
# 5        1.99      ZA  2022-11-04 17:31:21       broken clouds
# 6       17.85      GL  2022-11-04 17:31:21          light snow
# 7        6.91      NO  2022-11-04 17:31:21       broken clouds
# 8        4.90      RU  2022-11-04 17:31:21     overcast clouds
# 9        9.22      CA  2022-11-04 17:31:21    scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE
new_column_order = ["City", "Country", "Date", "Lat" ,"Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
# Recreate the DataFrame by using the new column order
city_data_df= city_data_df[new_column_order]
# Display sample data
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat      Lng  Max Temp  \
# 0           Abnub      EG  2022-11-04 17:31:21  27.2696  31.1511     73.62
# 1          Albany      US  2022-11-04 17:31:21  42.6001 -73.9662     69.26
# 2        Krutinka      RU  2022-11-04 17:31:21  56.0055  71.5113     34.36
# 3         Qaanaaq      GL  2022-11-04 17:31:21  77.4840 -69.3632     18.93
# 4  Barbosa Ferraz      BR  2022-11-04 17:31:21 -24.0300 -52.0117     74.43
# 5     Port Alfred      ZA  2022-11-04 17:31:21 -33.5906  26.8910     69.19
# 6        Tasiilaq      GL  2022-11-04 17:31:21  65.6145 -37.6368     30.36
# 7        Berlevag      NO  2022-11-04 17:31:21  70.8578  29.0864     41.00
# 8          Dikson      RU  2022-11-04 17:31:21  73.5069  80.5464     20.57
# 9    Fort Frances      CA  2022-11-04 17:31:21  48.5999 -93.4003     33.17
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        36           0       10.25           clear sky
# 1        55          29        3.00    scattered clouds
# 2        95         100       17.85                snow
# 3        66         100        7.63     overcast clouds
# 4        45           0        2.73           clear sky
# 5        89          82        1.99       broken clouds
# 6        83         100       17.85          light snow
# 7        81          75        6.91       broken clouds
# 8        96          98        4.90     overcast clouds
# 9        75          40        9.22    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Date                    object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"


# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
